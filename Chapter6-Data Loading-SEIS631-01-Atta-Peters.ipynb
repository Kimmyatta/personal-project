# %%
import pandas as pd
xlsx= pd.ExcelFile('ex1.xlsx')
pd.read_excel(xlsx, 'Sheet1')
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello
# 1   5,6,7,8,world
# 2  9,10,11,12,foo

# %%
xlsx= pd.ExcelFile('ex1-1.xlsx')
pd.read_excel(xlsx, 'Sheet2')
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello

# %%
frame=pd.read_excel('ex1.xlsx', 'Sheet1')
frame
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello
# 1   5,6,7,8,world
# 2  9,10,11,12,foo

# %%
xlsx= pd.ExcelFile('ex1-1.xlsx')
pd.read_excel(xlsx, 'Sheet2')
# Out:
#   a,b,c,d,message
# 0   1,2,3,4,hello

# %%
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data=resp.json()
display(data)
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61333',
#   'id': 3009380832,
#   'node_id': 'PR_kwDOAA0YD86TWY2A',
#   'number': 61333,
#   'title': 'CI: Have dedicated Python 3.13 job instead of using Python dev',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
# ...

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)
resp
data=resp.json()
display(data)
display(data[0]['title'])
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61333/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61333',
#   'id': 3009380832,
#   'node_id': 'PR_kwDOAA0YD86TWY2A',
#   'number': 61333,
#   'title': 'CI: Have dedicated Python 3.13 job instead of using Python dev',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
# ...

# %%
display(data[0]['title'])
# Out:
# 'CI: Have dedicated Python 3.13 job instead of using Python dev'

# %%
display(data[0]['title'])
display(data[0]['user'])
# Out:
# 'CI: Have dedicated Python 3.13 job instead of using Python dev'
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
# ...

# %%
issues=pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
display(issues)
# Out:
#     number                                              title  \
# 0    61333  CI: Have dedicated Python 3.13 job instead of ...
# 1    61332  CLN: Use newer numpy random Generator methods ...
# 2    61331                    DEPS: Clean unused dependencies
# 3    61328          BUG: pre-commit version 4.0.0 is required
# 4    61325             add test case for mixed string and int
# 5    61323  BUG: to_dict(orient='dict') does not convert n...
# 6    61322  BUG: memory issues with `string[pyarrow]` afte...
# 7    61321  Fix: AttributeError when using .iloc with pyar...
# 8    61320  PERF: Restore old performances with .isin() on...
# 9    61317  ENH: Make DataFrame.filter accept filters in n...
# 10   61316  BUG: `.to_parquet` fails with `schema` for `st...
# 11   61311  BUG: ``'ArrowExtensionArray' object has no att...
# 12   61308               ENH: Add tzdata to hard dependencies
# 13   61307  EHN: `df.to_latex(escape=True)` also escape in...
# ...

# %%
import sqlite3
query="""DROP TABLE IF EXISTS test;"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
query = """CREATE TABLE test (a VARCHAR(20), b VARCHAR(20), C REAL, d INTEGER);"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
data= [('Atlanta', 'Georgia', 1.25,6),
('Tallahassee', 'Florida', 2.6, 3),
('Sacramento', 'California', 1.7, 5)]
stmt= "INSERT INTO test VALUES(?,?,?,?)"
con.executemany(stmt,data)

# %%
cursor =con.execute('select * from test')
rows = cursor.fetchall()
display(rows)
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor =con.execute('select * from test where d > 4')
rows = cursor.fetchall()
display(rows)
# Out:
# [('Atlanta', 'Georgia', 1.25, 6), ('Sacramento', 'California', 1.7, 5)]

# %%
cursor =con.execute('select * from test where d > 5')
rows = cursor.fetchall()
display(rows)
# Out:
# [('Atlanta', 'Georgia', 1.25, 6)]

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...

# %%
import sqlalchemy as db
engine= db.create_engine('sqlite:///cars.db')

# %%
import sqlite3

connection  = sqlite3.connect('cars.db')

cursor = connection.cursor()
cursor.execute('''DROP TABLE IF EXISTS cars''')
connection.commit()

cursor.execute('''
CREATE TABLE IF NOT EXISTS cars
  (
    make    TEXT,
    model  TEXT,
    year     INT
  )
    ''')
connection.commit()
cursor = connection.cursor()
cursor.execute("INSERT INTO cars VALUES ('Ford', 'Mustang Mach E', 2022)")
connection.commit()

cool_cars = [('Tesla', 'Model 3', 2020),
             ('Kia', 'Niro EV', 2022),
             ('Porsche', 'Taycan 4s', 2021)]

cursor.executemany('INSERT INTO cars VALUES(?,?,?)', cool_cars)
connection.commit()

cursor.execute("SELECT * FROM cars")
record = cursor.fetchone()

print(record)

record = cursor.fetchall()

print(record)

connection.commit()
connection.close()
# Out:
# ('Ford', 'Mustang Mach E', 2022)
# [('Tesla', 'Model 3', 2020), ('Kia', 'Niro EV', 2022), ('Porsche', 'Taycan 4s', 2021)]
